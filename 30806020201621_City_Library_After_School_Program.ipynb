# %%
import pandas as pd
import sqlite3
import numpy as np
conn = sqlite3.connect("/content/db")

#Task 1 بسم الله
#required 1
req1="""SELECT m.member_id, m.first_name, COUNT(c.checkout_id) AS checkout_count
FROM members m
LEFT JOIN checkouts c
ON m.member_id = c.member_id
GROUP BY m.member_id """
result = pd.read_sql_query(req1, conn)
print(result)
conn.close()
# Out:
#     member_id first_name  checkout_count
# 0        1001      Salma               1
# 1        1002      Fares               2
# 2        1003     Bassel               9
# 3        1004      Fares               0
# 4        1005    Youssef               3
# ..        ...        ...             ...
# 75       1076       Dina               7
# 76       1077       Lina               6
# 77       1078     Habiba               0
# 78       1079       Rana              10
# 79       1080     Bassel               2
#
# [80 rows x 3 columns]

# %%
#follow task 1 req 2
conn = sqlite3.connect("/content/db")
req2 = """
SELECT book_id, title, author
FROM books
WHERE author LIKE 'S%'
"""

result2 = pd.read_sql_query(req2, conn)
print(result2)
# Out:
#    book_id                   title        author
# 0      529  Riddles of the Red Sea  Sara Tantawy
# 1      530       The Sandstone Key  Sara Tantawy
# 2      531   Voices in the Library   Samir Zohdy
# 3      532       The Last Bookmark   Samir Zohdy

# %%
#follow task 1 req 3
req3="""SELECT b.title, COUNT(c.checkout_id) AS count
FROM books b
JOIN checkouts c
ON b.book_id = c.book_id
GROUP BY b.title
ORDER BY count DESC
LIMIT 5 """
result3 = pd.read_sql_query(req3, conn)
print(result3)
# Out:
#                     title  count
# 0         The Silver Kite     57
# 1   Fossils and Fireflies     55
# 2  Circuits for Beginners     46
# 3        Kites Over Cairo     38
# 4    Storms and Sailboats     25

# %%
#follow task 1 req 4
req4="""SELECT m.member_id, m.first_name, COUNT(c.checkout_id) AS borrowed
FROM members m
JOIN checkouts c
ON m.member_id = c.member_id
GROUP BY m.member_id
ORDER BY borrowed DESC
LIMIT 10"""
result4 = pd.read_sql_query(req4, conn)
print(result4)
# Out:
#    member_id first_name  borrowed
# 0       1034        Aya        25
# 1       1044     Sherif        21
# 2       1008       Ziad        19
# 3       1027    Mostafa        18
# 4       1010       Nour        18
# 5       1065       Adam        17
# 6       1024    Youssef        17
# 7       1018      Ahmed        17
# 8       1047       Sara        16
# 9       1030       Reem        16

# %%
#follow task 1 req 5
req5="""SELECT *
FROM checkouts
JOIN members
ON checkouts.member_id = members.member_id
WHERE neighborhood = 'Nasr City'
ORDER BY checkout_date DESC
LIMIT 10 OFFSET 10"""
result5 = pd.read_sql_query(req5, conn)
print(result5)
# Out:
#    checkout_id  member_id  book_id checkout_date return_date  member_id  \
# 0         9144       1024      501    2025-11-07  2025-11-25       1024
# 1         9375       1034      525    2025-10-27  2025-11-15       1034
# 2         9376       1024      518    2025-10-22  2025-11-04       1024
# 3         9185       1026      519    2025-10-22  2025-11-01       1026
# 4         9170       1034      522    2025-10-16  2025-10-28       1034
# 5         9124       1024      525    2025-10-14  2025-11-13       1024
# 6         9150       1024      507    2025-10-14  2025-10-24       1024
# 7         9161       1040      519    2025-10-11  2025-11-01       1040
# 8         9147       1028      512    2025-10-05  2025-11-01       1028
# 9         9143       1024      518    2025-10-02        None       1024
#
#   first_name last_name  grade neighborhood membership_status   join_date
# 0    Youssef    Hegazy      8    Nasr City          inactive  2024-01-04
# 1        Aya     Wahba      9    Nasr City            Active  2025-01-22
# 2    Youssef    Hegazy      8    Nasr City          inactive  2024-01-04
# 3       Nada     Saleh      7    Nasr City          inactive  2023-11-16
# 4        Aya     Wahba      9    Nasr City            Active  2025-01-22
# 5    Youssef    Hegazy      8    Nasr City          inactive  2024-01-04
# 6    Youssef    Hegazy      8    Nasr City          inactive  2024-01-04
# 7       Dina      Adel      9    Nasr City            Active  2025-12-26
# 8     Hassan      Adel      9    Nasr City            Active  2025-11-12
# 9    Youssef    Hegazy      8    Nasr City          inactive  2024-01-04

# %%
#combiend task
members = pd.read_sql_query("SELECT * FROM members", conn)
checkouts = pd.read_sql_query("SELECT * FROM checkouts", conn)

combined = members.merge(checkouts,on="member_id",how="left"
)

print(combined.shape)
print(combined.head())
# Out:
# (409, 11)
#    member_id first_name last_name  grade neighborhood membership_status  \
# 0       1001      Salma   Ibrahim    8.0        Maadi            Active
# 1       1002      Fares     Saleh    9.0        Maadi            Active
# 2       1002      Fares     Saleh    9.0        Maadi            Active
# 3       1003     Bassel    Hegazy    6.0        Maadi            Active
# 4       1003     Bassel    Hegazy    6.0        Maadi            Active
#
#     join_date  checkout_id  book_id checkout_date return_date
# 0  2023-04-05       9025.0    525.0    2024-10-24  2024-11-07
# 1        None       9013.0    501.0    2024-02-16  2024-02-29
# 2        None       9095.0    507.0    2024-06-25  2024-07-07
# 3  2025-04-23       9051.0    513.0    2025-07-22  2025-08-18
# 4  2025-04-23       9068.0    501.0    2025-11-14  2025-12-03

# %%
#follow combiend task
books = pd.read_sql_query("SELECT * FROM books", conn)
combined = combined.merge( books,on="book_id",how="left")
print(combined.shape)
print(combined.head())
# Out:
# (409, 13)
#    member_id first_name last_name  grade neighborhood membership_status  \
# 0       1001      Salma   Ibrahim    8.0        Maadi            Active
# 1       1002      Fares     Saleh    9.0        Maadi            Active
# 2       1002      Fares     Saleh    9.0        Maadi            Active
# 3       1003     Bassel    Hegazy    6.0        Maadi            Active
# 4       1003     Bassel    Hegazy    6.0        Maadi            Active
#
#     join_date  checkout_id  book_id checkout_date return_date  \
# 0  2023-04-05       9025.0    525.0    2024-10-24  2024-11-07
# 1        None       9013.0    501.0    2024-02-16  2024-02-29
# 2        None       9095.0    507.0    2024-06-25  2024-07-07
# 3  2025-04-23       9051.0    513.0    2025-07-22  2025-08-18
# 4  2025-04-23       9068.0    501.0    2025-11-14  2025-12-03
#
#                     title         author
# 0    Storms and Sailboats  Mahmoud Rafei
# 1         The Silver Kite  Amina Darwish
# 2   Fossils and Fireflies    Dalia Serry
# 3  Circuits for Beginners   Galal Mounir
# 4         The Silver Kite  Amina Darwish

# %%
import os
df=pd.read_html("/content/html")
print(df[0])
print(df[0].shape)
print(df[0].head())
# Out:
#     Member ID  Book ID Checkout Date
# 0        1026      522    2025-07-11
# 1        1049      520    2025-07-11
# 2        1062      525    2025-07-05
# 3        1065      520    2025-07-07
# 4        1104      515    2025-07-07
# 5        1009      503    2025-07-09
# 6        1063      522    2025-07-07
# 7        1022      511    2025-07-12
# 8        1029      523    2025-07-09
# 9        1201      509    2025-07-10
# 10       1005      513    2025-07-10
# 11       1104      526    2025-07-05
# 12       1058      518    2025-07-08
# 13       1002      521    2025-07-08
# 14       1150      530    2025-07-10
# 15       1041      504    2025-07-05
# 16       1055      526    2025-07-11
# 17       1061      513    2025-07-06
# 18       1012      509    2025-07-11
# 19       1007      510    2025-07-07
# 20       1073      530    2025-07-07
# 21       1003      501    2025-07-08
# 22       1017      507    2025-07-11
# 23       1061      504    2025-07-06
# 24       1201      523    2025-07-08
# 25       1041      512    2025-07-06
# (26, 3)
#    Member ID  Book ID Checkout Date
# 0       1026      522    2025-07-11
# 1       1049      520    2025-07-11
# 2       1062      525    2025-07-05
# 3       1065      520    2025-07-07
# 4       1104      515    2025-07-07

# %%
df = pd.read_html("/content/html")[0]

df = df.rename(columns={"Member ID": "member_id","Book ID": "book_id","Checkout Date": "checkout_date"
})

combined = pd.concat([combined, df], ignore_index=True)

print(combined.shape)
print(combined.head())
# Out:
# (435, 13)
#    member_id first_name last_name  grade neighborhood membership_status  \
# 0       1001      Salma   Ibrahim    8.0        Maadi            Active
# 1       1002      Fares     Saleh    9.0        Maadi            Active
# 2       1002      Fares     Saleh    9.0        Maadi            Active
# 3       1003     Bassel    Hegazy    6.0        Maadi            Active
# 4       1003     Bassel    Hegazy    6.0        Maadi            Active
#
#     join_date  checkout_id  book_id checkout_date return_date  \
# 0  2023-04-05       9025.0    525.0    2024-10-24  2024-11-07
# 1        None       9013.0    501.0    2024-02-16  2024-02-29
# 2        None       9095.0    507.0    2024-06-25  2024-07-07
# 3  2025-04-23       9051.0    513.0    2025-07-22  2025-08-18
# 4  2025-04-23       9068.0    501.0    2025-11-14  2025-12-03
#
#                     title         author
# 0    Storms and Sailboats  Mahmoud Rafei
# 1         The Silver Kite  Amina Darwish
# 2   Fossils and Fireflies    Dalia Serry
# 3  Circuits for Beginners   Galal Mounir
# 4         The Silver Kite  Amina Darwish

# %%
with open("/content/task1_sql_answers.txt", "w", encoding="utf-8") as f:

    f.write("Task 1 - SQL Answers")

    f.write("Question 1: How much is each member borrowing?")
    f.write("SQL:\n")
    f.write(req1)
    f.write("\nResult:\n")
    f.write(result.to_string(index=False))
    f.write("\n\n" + "="*60 + "\n\n")
    f.write("Question 2: Which books match a chosen author pattern?\n\n")
    f.write("SQL:\n")
    f.write(req2)
    f.write("\nResult:\n")
    f.write(result2.to_string(index=False))
    f.write("\n\n" + "="*60 + "\n\n")
    f.write("Question 3: What are the most popular books?\n\n")
    f.write("SQL:\n")
    f.write(req3)
    f.write("\nResult:\n")
    f.write(result3.to_string(index=False))
    f.write("\n\n" + "="*60 + "\n\n")
    f.write("Question 4: Who are the most active readers?\n\n")
    f.write("SQL:\n")
    f.write(req4)
    f.write("\nResult:\n")
    f.write(result4.to_string(index=False))
    f.write("\n\n" + "="*60 + "\n\n")
    f.write("Question 5: What does a neighborhood's activity look like further back in time?\n\n")
    f.write("SQL:\n")
    f.write(req5)
    f.write("\nResult:\n")
    f.write(result5.to_string(index=False))
    f.write("\n\n" + "="*60 + "\n\n")

    f.write("Web Page vs Database Reflection\n\n")
    f.write("The database stores structured data that can be queried directly using SQL.\n")
    f.write("The Reading Kickoff data was on a web page, so I had to read the page and convert its table into data.\n")
    f.write("This mattered because the two sources provide data in different ways.\n")

print("task1_sql_answers.txt created successfully!")
# Out:
# task1_sql_answers.txt created successfully!

# %%
combined.to_csv("/content/combined_task1_30806020201621_library_data.csv", index=False)
print("Task 1  IS OVERRRR!")
# Out:
# Task 1  IS OVERRRR!

# %%
#TASK 2 بسم الله
#explore data
data=pd.read_csv("/content/combined_task1_30806020201621_library_data.csv")
print(data.shape)
print(data.head())
print(data.describe())
print(data.info())
# Out:
# (435, 13)
#    member_id first_name last_name  grade neighborhood membership_status  \
# 0       1001      Salma   Ibrahim    8.0        Maadi            Active
# 1       1002      Fares     Saleh    9.0        Maadi            Active
# 2       1002      Fares     Saleh    9.0        Maadi            Active
# 3       1003     Bassel    Hegazy    6.0        Maadi            Active
# 4       1003     Bassel    Hegazy    6.0        Maadi            Active
#
#     join_date  checkout_id  book_id checkout_date return_date  \
# 0  2023-04-05       9025.0    525.0    2024-10-24  2024-11-07
# 1         NaN       9013.0    501.0    2024-02-16  2024-02-29
# 2         NaN       9095.0    507.0    2024-06-25  2024-07-07
# 3  2025-04-23       9051.0    513.0    2025-07-22  2025-08-18
# 4  2025-04-23       9068.0    501.0    2025-11-14  2025-12-03
#
#                     title         author
# 0    Storms and Sailboats  Mahmoud Rafei
# 1         The Silver Kite  Amina Darwish
# 2   Fossils and Fireflies    Dalia Serry
# 3  Circuits for Beginners   Galal Mounir
# 4         The Silver Kite  Amina Darwish
#          member_id       grade  checkout_id     book_id
# count   435.000000  371.000000   391.000000  417.000000
# mean   1041.117241    7.560647  9192.611253  513.443645
# std      26.126819    1.152419   110.279771    8.976053
# min    1001.000000    6.000000  9001.000000  501.000000
# 25%    1020.000000    7.000000  9097.500000  507.000000
# 50%    1038.000000    8.000000  9193.000000  513.000000
# 75%    1061.000000    9.000000  9287.500000  519.000000
# max    1201.000000    9.000000  9383.000000  532.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   member_id          435 non-null    int64
#  1   first_name         409 non-null    object
#  2   last_name          409 non-null    object
#  3   grade              371 non-null    float64
#  4   neighborhood       409 non-null    object
#  5   membership_status  409 non-null    object
#  6   join_date          403 non-null    object
#  7   checkout_id        391 non-null    float64
#  8   book_id            417 non-null    float64
#  9   checkout_date      417 non-null    object
#  10  return_date        326 non-null    object
#  11  title              391 non-null    object
#  12  author             391 non-null    object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 44.3+ KB
# None

# %%
from google.colab import files
files.download("/content/git_log.txt")

# %%
print(data.duplicated().sum())
print(data.isna().sum())
# Out:
# 8
# member_id              0
# first_name            26
# last_name             26
# grade                 64
# neighborhood          26
# membership_status     26
# join_date             32
# checkout_id           44
# book_id               18
# checkout_date         18
# return_date          109
# title                 44
# author                44
# dtype: int64

# %%
data=data.drop_duplicates()
print(data.shape)
# Out:
# (427, 13)

# %%
#نعالجج الميسينج فاليو
columns_treat_by_mode = [
    "first_name",
    "last_name",
    "neighborhood",
    "membership_status",
    "join_date",
    "checkout_date",
    "return_date",
    "title",
    "author"
]

for col in columns_treat_by_mode:
    data[col] = data[col].fillna(data[col].mode()[0])

data["grade"] = data["grade"].fillna(data["grade"].median())
data["checkout_id"] = data["checkout_id"].fillna("No Checkout")
data["book_id"] = data["book_id"].fillna("No Book")

print(data.isna().sum())
# Out:
# member_id            0
# first_name           0
# last_name            0
# grade                0
# neighborhood         0
# membership_status    0
# join_date            0
# checkout_id          0
# book_id              0
# checkout_date        0
# return_date          0
# title                0
# author               0
# dtype: int64

# %%
#نعالج مشاكل ال consistence
data["neighborhood"]=data["neighborhood"].str.strip().str.title()
data['membership_status']=data['membership_status'].str.strip().str.title()
print(data)
# Out:
#      member_id first_name last_name  grade neighborhood membership_status  \
# 0         1001      Salma   Ibrahim    8.0        Maadi            Active
# 1         1002      Fares     Saleh    9.0        Maadi            Active
# 2         1002      Fares     Saleh    9.0        Maadi            Active
# 3         1003     Bassel    Hegazy    6.0        Maadi            Active
# 4         1003     Bassel    Hegazy    6.0        Maadi            Active
# ..         ...        ...       ...    ...          ...               ...
# 430       1003      Ahmed     Fahmy    8.0    Nasr City            Active
# 431       1017      Ahmed     Fahmy    8.0    Nasr City            Active
# 432       1061      Ahmed     Fahmy    8.0    Nasr City            Active
# 433       1201      Ahmed     Fahmy    8.0    Nasr City            Active
# 434       1041      Ahmed     Fahmy    8.0    Nasr City            Active
#
#       join_date  checkout_id book_id checkout_date return_date  \
# 0    2023-04-05       9025.0   525.0    2024-10-24  2024-11-07
# 1    2025-01-22       9013.0   501.0    2024-02-16  2024-02-29
# 2    2025-01-22       9095.0   507.0    2024-06-25  2024-07-07
# 3    2025-04-23       9051.0   513.0    2025-07-22  2025-08-18
# 4    2025-04-23       9068.0   501.0    2025-11-14  2025-12-03
# ..          ...          ...     ...           ...         ...
# 430  2025-01-22  No Checkout   501.0    2025-07-08  2024-08-12
# 431  2025-01-22  No Checkout   507.0    2025-07-11  2024-08-12
# 432  2025-01-22  No Checkout   504.0    2025-07-06  2024-08-12
# 433  2025-01-22  No Checkout   523.0    2025-07-08  2024-08-12
# 434  2025-01-22  No Checkout   512.0    2025-07-06  2024-08-12
#
#                       title         author
# 0      Storms and Sailboats  Mahmoud Rafei
# 1           The Silver Kite  Amina Darwish
# 2     Fossils and Fireflies    Dalia Serry
# 3    Circuits for Beginners   Galal Mounir
# 4           The Silver Kite  Amina Darwish
# ..                      ...            ...
# 430         The Silver Kite  Amina Darwish
# 431         The Silver Kite  Amina Darwish
# 432         The Silver Kite  Amina Darwish
# 433         The Silver Kite  Amina Darwish
# 434         The Silver Kite  Amina Darwish
#
# [427 rows x 13 columns]

# %%
#نشوف ال wrong ids
wrong_ids = [1104, 1150, 1201]
print(data[data["member_id"].isin(wrong_ids)])
data = data[~data["member_id"].isin(wrong_ids)]
print(data)
# Out:
#      member_id first_name last_name  grade neighborhood membership_status  \
# 413       1104      Ahmed     Fahmy    8.0    Nasr City            Active
# 418       1201      Ahmed     Fahmy    8.0    Nasr City            Active
# 420       1104      Ahmed     Fahmy    8.0    Nasr City            Active
# 423       1150      Ahmed     Fahmy    8.0    Nasr City            Active
# 433       1201      Ahmed     Fahmy    8.0    Nasr City            Active
#
#       join_date  checkout_id book_id checkout_date return_date  \
# 413  2025-01-22  No Checkout   515.0    2025-07-07  2024-08-12
# 418  2025-01-22  No Checkout   509.0    2025-07-10  2024-08-12
# 420  2025-01-22  No Checkout   526.0    2025-07-05  2024-08-12
# 423  2025-01-22  No Checkout   530.0    2025-07-10  2024-08-12
# 433  2025-01-22  No Checkout   523.0    2025-07-08  2024-08-12
#
#                title         author
# 413  The Silver Kite  Amina Darwish
# 418  The Silver Kite  Amina Darwish
# 420  The Silver Kite  Amina Darwish
# 423  The Silver Kite  Amina Darwish
# 433  The Silver Kite  Amina Darwish
#      member_id first_name last_name  grade neighborhood membership_status  \
# 0         1001      Salma   Ibrahim    8.0        Maadi            Active
# 1         1002      Fares     Saleh    9.0        Maadi            Active
# 2         1002      Fares     Saleh    9.0        Maadi            Active
# 3         1003     Bassel    Hegazy    6.0        Maadi            Active
# 4         1003     Bassel    Hegazy    6.0        Maadi            Active
# ..         ...        ...       ...    ...          ...               ...
# 429       1073      Ahmed     Fahmy    8.0    Nasr City            Active
# 430       1003      Ahmed     Fahmy    8.0    Nasr City            Active
# 431       1017      Ahmed     Fahmy    8.0    Nasr City            Active
# 432       1061      Ahmed     Fahmy    8.0    Nasr City            Active
# 434       1041      Ahmed     Fahmy    8.0    Nasr City            Active
#
#       join_date  checkout_id book_id checkout_date return_date  \
# 0    2023-04-05       9025.0   525.0    2024-10-24  2024-11-07
# 1    2025-01-22       9013.0   501.0    2024-02-16  2024-02-29
# 2    2025-01-22       9095.0   507.0    2024-06-25  2024-07-07
# 3    2025-04-23       9051.0   513.0    2025-07-22  2025-08-18
# 4    2025-04-23       9068.0   501.0    2025-11-14  2025-12-03
# ..          ...          ...     ...           ...         ...
# 429  2025-01-22  No Checkout   530.0    2025-07-07  2024-08-12
# 430  2025-01-22  No Checkout   501.0    2025-07-08  2024-08-12
# 431  2025-01-22  No Checkout   507.0    2025-07-11  2024-08-12
# 432  2025-01-22  No Checkout   504.0    2025-07-06  2024-08-12
# 434  2025-01-22  No Checkout   512.0    2025-07-06  2024-08-12
#
#                       title         author
# 0      Storms and Sailboats  Mahmoud Rafei
# 1           The Silver Kite  Amina Darwish
# 2     Fossils and Fireflies    Dalia Serry
# 3    Circuits for Beginners   Galal Mounir
# 4           The Silver Kite  Amina Darwish
# ..                      ...            ...
# 429         The Silver Kite  Amina Darwish
# 430         The Silver Kite  Amina Darwish
# 431         The Silver Kite  Amina Darwish
# 432         The Silver Kite  Amina Darwish
# 434         The Silver Kite  Amina Darwish
#
# [422 rows x 13 columns]

# %%
data.to_csv("task2_cleaned_30806020201621_data.csv", index=False)
print("Task 2 IS OVERRRR!")
# Out:
# Task 2 IS OVERRRR!

# %%
#task3

data = pd.read_csv("/content/task2_cleaned_30806020201621_data.csv")
members = data.groupby("neighborhood")["member_id"].nunique()
checkouts = data[data["checkout_id"] != "No Checkout"].groupby("neighborhood").size()
fairness = pd.DataFrame({ "Members": members,"Checkouts": checkouts
}).fillna(0)

print(fairness)
# Out:
#               Members  Checkouts
# neighborhood
# Heliopolis         18       84.0
# Maadi              22      106.0
# Nasr  City          1        0.0
# Nasr City          35       97.0
# Shubra              6       34.0
# Zamalek            14       62.0

# %%
#task3 completeedddddd
